# %%
print("ok")
# Out:
# ok

# %%
# %pip install -U langchain-community
# Out:
# Requirement already satisfied: langchain-community in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (0.2.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain-community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain-community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain-community) (0.5.14)
# Requirement already satisfied: langchain<0.3.0,>=0.2.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain-community) (0.2.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain-community) (0.2.5)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain-community) (0.1.77)
# Requirement already satisfied: numpy<2,>=1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain-community) (1.24.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain-community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain<0.3.0,>=0.2.0->langchain-community) (0.2.1)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain<0.3.0,>=0.2.0->langchain-community) (1.10.15)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain-community) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain-community) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.10.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests<3,>=2->langchain-community) (2024.6.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain-community) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Pinecone
import pinecone
from pinecone import Pinecone
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain.llms import CTransformers

# %%
PINECONE_API_KEY="3ca654dc-2db3-4444-abe8-f5c5a6a70c23"
PINECONE_API_ENV="us-east-1"

# %%
# Extract pdf data
from unittest import loader


def load_pdf(data):
    directory_loader = DirectoryLoader(data, 
                                       glob="*.pdf",
                                       loader_cls=PyPDFLoader)
    
    documents = directory_loader.load()

    return documents

# %%
extracted_data = load_pdf("data/")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 extracted_data = load_pdf("data/")
#
# NameError: name 'load_pdf' is not defined

# %%
extracted_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 extracted_data
#
# NameError: name 'extracted_data' is not defined

# %%
def text_split(extracted_data):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 20)
    text_chunks = text_splitter.split_documents(extracted_data)

    return text_chunks

# %%
text_chunks = text_split(extracted_data)
# print(text_chunks)
print(len(text_chunks))
# Out:
# 7020

# %% [markdown]
# ##  download embedding model

# %%
def download_hugging_face_embeddings():
    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
    return embeddings

# %%
embeddings = download_hugging_face_embeddings()

# %%
embeddings
# Out:
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# ), model_name='sentence-transformers/all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={})

# %%
query_result = embeddings.embed_query("Hello world")
print("length", len(query_result))
# Out:
# length 384

# %%
query_result
# Out:
# [-0.03447727486491203,
#  0.03102317824959755,
#  0.006734970025718212,
#  0.026108985766768456,
#  -0.03936202451586723,
#  -0.16030244529247284,
#  0.06692401319742203,
#  -0.006441489793360233,
#  -0.0474504791200161,
#  0.014758856035768986,
#  0.07087527960538864,
#  0.05552763119339943,
#  0.019193334504961967,
#  -0.026251312345266342,
#  -0.01010954286903143,
#  -0.02694045566022396,
#  0.022307461127638817,
#  -0.022226648405194283,
#  -0.14969263970851898,
#  -0.017493007704615593,
#  0.00767625542357564,
#  0.05435224249958992,
#  0.0032543970737606287,
#  0.031725890934467316,
#  -0.0846213847398758,
#  -0.02940601296722889,
#  0.05159561336040497,
#  0.04812406003475189,
#  -0.0033148222137242556,
#  -0.058279167860746384,
#  0.04196927323937416,
#  0.022210685536265373,
#  0.1281888335943222,
#  -0.022338971495628357,
#  -0.011656315997242928,
#  0.06292839348316193,
#  -0.032876335084438324,
#  -0.09122604131698608,
#  -0.031175347045063972,
#  0.0526994913816452,
#  0.04703482985496521,
#  -0.08420311659574509,
#  -0.030056199058890343,
#  -0.02074483036994934,
#  0.009517835453152657,
#  -0.0037217906210571527,
#  0.007343285251408815,
#  0.03932438790798187,
#  0.0932740643620491,
#  -0.003788596484810114,
#  -0.052742067724466324,
#  -0.05805816128849983,
#  -0.006864361464977264,
#  0.005283191800117493,
#  0.0828929990530014,
#  0.019362755119800568,
#  0.0062844837084412575,
#  -0.010330787859857082,
#  0.009032378904521465,
#  -0.037683695554733276,
#  -0.04520607739686966,
#  0.024016305804252625,
#  -0.006944137159734964,
#  0.013491630554199219,
#  0.10005494207143784,
#  -0.07168391346931458,
#  -0.021695120260119438,
#  0.031618405133485794,
#  -0.051634665578603745,
#  -0.08224772661924362,
#  -0.06569333374500275,
#  -0.00989533495157957,
#  0.005816374905407429,
#  0.07355456054210663,
#  -0.034050311893224716,
#  0.0248861201107502,
#  0.014488042332231998,
#  0.02645738422870636,
#  0.009656722657382488,
#  0.0302172489464283,
#  0.05280393362045288,
#  -0.07535984367132187,
#  0.009897145442664623,
#  0.029836809262633324,
#  0.01755557768046856,
#  0.023091984912753105,
#  0.001933806692250073,
#  0.0014002545503899455,
#  -0.04717595875263214,
#  -0.011194315738976002,
#  -0.11420144140720367,
#  -0.019811924546957016,
#  0.040266189724206924,
#  0.0021929906215518713,
#  -0.07979220896959305,
#  -0.02538231760263443,
#  -0.0757884755730629,
#  0.027527665719389915,
#  0.07462543249130249,
#  0.01771726831793785,
#  0.09121846407651901,
#  0.11022016406059265,
#  0.0005697731394320726,
#  0.05146336182951927,
#  -0.014551310800015926,
#  0.03323203697800636,
#  0.023792240768671036,
#  -0.02288980595767498,
#  0.038937538862228394,
#  0.030206844210624695]

# %%
from pinecone.grpc import PineconeGRPC as Pinecone, ServerlessSpec

pc = Pinecone(api_key='YOUR_API_KEY')

# Create a new index
index_name = "medical-chatbot"

if index_name not in pc.list_indexes().names():
    pc.create_index(
        name=index_name,
        dimension=384,
        metric="cosine",
        spec=ServerlessSpec(
            cloud='aws', 
            region='us-east-1'
        ) 
    ) 

index = pc.Index(index_name)

index.upsert(
    vectors=[
        {"id": "vec1", "values": [1.0, 1.5]},
        {"id": "vec2", "values": [2.0, 1.0]},
        {"id": "vec3", "values": [0.1, 3.0]},
    ],
    namespace="ns1"
)
#upsert vectors

index.upsert(
    vectors=[
        {"id": "vec1", "values": [1.0, -2.5]},
        {"id": "vec2", "values": [3.0, -2.0]},
        {"id": "vec3", "values": [0.5, -1.5]},
    ],
    namespace="ns2"
)
# check for indexes
print(index.describe_index_stats())

# Returns:
# {'dimension': 2,
#  'index_fullness': 0.0,
#  'namespaces': {'ns1': {'vector_count': 3}, 'ns2': {'vector_count': 3}},
#  'total_vector_count': 6}
  

  #runs similarity search
query_results1 = index.query(
    namespace="ns1",
    vector=[1.0, 1.5],
    top_k=3,
    include_values=True
)

print(query_results1)

query_results2 = index.query(
    namespace="ns2",
    vector=[1.0,-2.5],
    top_k=3,
    include_values=True
)

print(query_results2)

# Returns:
# {'matches': [{'id': 'vec1', 'score': 1.0, 'values': [1.0, 1.5]},
#              {'id': 'vec2', 'score': 0.868243158, 'values': [2.0, 1.0]},
#              {'id': 'vec3', 'score': 0.850068152, 'values': [0.1, 3.0]}],
#  'namespace': 'ns1',
#  'usage': {'read_units': 6}}
# {'matches': [{'id': 'vec1', 'score': 1.0, 'values': [1.0, -2.5]},
#              {'id': 'vec3', 'score': 0.998274386, 'values': [0.5, -1.5]},
#              {'id': 'vec2', 'score': 0.824041963, 'values': [3.0, -2.0]}],
#  'namespace': 'ns2',
#  'usage': {'read_units': 6}}
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from pinecone.grpc import PineconeGRPC as Pinecone, ServerlessSpec
#       3 pc = Pinecone(api_key='YOUR_API_KEY')
#       5 # Create a new index
#
# ImportError: cannot import name 'ServerlessSpec' from 'pinecone.grpc' (c:\Users\MIKE\miniconda3\envs\mchatbot\lib\site-packages\pinecone\grpc\__init__.py)

# %%
# %pip install pinecone
# %pip install langchain_community
# Out:
# Requirement already satisfied: pinecone in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (4.0.0)
# Requirement already satisfied: certifi>=2019.11.17 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from pinecone) (2024.6.2)
# Requirement already satisfied: tqdm>=4.64.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from pinecone) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from pinecone) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from pinecone) (2.2.1)
# Requirement already satisfied: colorama in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from tqdm>=4.64.1->pinecone) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain_community in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (0.2.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: PyYAML>=5.3 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain_community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain_community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain_community) (0.5.14)
# Requirement already satisfied: langchain<0.3.0,>=0.2.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain_community) (0.2.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain_community) (0.2.5)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain_community) (0.1.77)
# Requirement already satisfied: numpy<2,>=1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain_community) (1.24.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain_community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (0.2.1)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (1.10.15)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain_community) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain_community) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests<3,>=2->langchain_community) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests<3,>=2->langchain_community) (2024.6.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain_community) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)

# %%
import os
from pinecone import Pinecone

os.environ['PINECONE_API_KEY'] = '83655f48-c25b-4286-a2f1-146da0924de9'

pinecone_instance = Pinecone(api_key='83655f48-c25b-4286-a2f1-146da0924de9', environment='gcp-starter') #I dont think this line does anything but sijaitoa just incase

index_name = "medical-chatbot"

# Create a PineconeVectorStore instance with the Pinecone instance and index
from langchain_pinecone import PineconeVectorStore

docsearch = PineconeVectorStore.from_texts([t.page_content for t in text_chunks], embeddings, index_name=index_name)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 11
#       8 index_name = "medical-chatbot"
#      10 # Create a PineconeVectorStore instance with the Pinecone instance and index
# ---> 11 from langchain_pinecone import PineconeVectorStore
#      13 docsearch = PineconeVectorStore.from_texts([t.page_content for t in text_chunks], embeddings, index_name=index_name)
#
# ModuleNotFoundError: No module named 'langchain_pinecone'
